# %% [markdown]
# ### Get data about business using Yelp
# This notebook does the following:
# - Loads the locations of bars from a file
# - Uses geo search on Yelp API to identify the bar and get information about price and rating

# %%
import geopandas as gpd
import pandas as pd
import shapely
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
barLocDF = pd.read_csv('partynyc/bar_locations.csv')

# %%
barLocDF.head()
# Out:
#          Location Type  Incident Zip           City        Borough   Latitude  \
# 0  Club/Bar/Restaurant       10308.0  STATEN ISLAND  STATEN ISLAND  40.544096
# 1  Club/Bar/Restaurant       10012.0       NEW YORK      MANHATTAN  40.729793
# 2  Club/Bar/Restaurant       10308.0  STATEN ISLAND  STATEN ISLAND  40.544209
# 3  Club/Bar/Restaurant       10034.0       NEW YORK      MANHATTAN  40.866376
# 4  Club/Bar/Restaurant       11220.0       BROOKLYN       BROOKLYN  40.635207
#
#    Longitude  num_calls
# 0 -74.141155         40
# 1 -73.998842         18
# 2 -74.141040         21
# 3 -73.928258        160
# 4 -74.020285         17

# %%
from __future__ import print_function

import json
import requests
import sys
import urllib

try:
    # For Python 3.0 and later
    from urllib.error import HTTPError
    from urllib.parse import quote
    from urllib.parse import urlencode
except ImportError:
    # Fall back to Python 2's urllib2 and urllib
    from urllib2 import HTTPError
    from urllib import quote
from urllib import urlencode

# %%
API_KEY = 'INSERT KEY HERE'

# %%
# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.
EVENTS_PATH = '/v3/events'

# %%
def request(host, path, api_key, url_params=None):
    """Given your API_KEY, send a GET request to the API.
    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        API_KEY (str): Your API Key.
        url_params (dict): An optional set of query parameters in the request.
    Returns:
        dict: The JSON response from the request.
    Raises:
        HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()

# %%
def search(term, lat, lon):
    """Query the Search API by a search term and location.
    Args:
        term (str): The search term passed to the API.
        location (str): The search location passed to the API.
    Returns:
        dict: The JSON response from the request.
    """

    url_params = {
        'term': term.replace(' ', '+'),
        'latitude': lat,
        'longitude': lon,
        'limit': SEARCH_LIMIT,
        'sort_by': SORTER
    }
    return request(API_HOST, SEARCH_PATH, API_KEY, url_params=url_params)

# %% [markdown]
# ## Business

# %%
SEARCH_LIMIT = 1
TERM = 'nightlife'
RADIUS = 4000
SORTER = 'distance'

# %%
nightLife = []
for i in range(len(barLocDF)):
    data = search(TERM,lat = barLocDF.loc[i,'Latitude'], lon = barLocDF.loc[i,'Longitude'])
    nightLife.append(data)
    print(str(i)+': '+str(len(data['businesses'])))
    filename = 'puma_nightlife/'+str(i)+'.json'
    with open(filename, 'w') as fp:
        json.dump(data, fp)
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# 0: 1
# Querying https://api.yelp.com/v3/businesses/search ...
#
 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 753: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 754: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 755: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 756: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 757: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 758: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 759: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 760: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 761: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 762: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 763: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 764: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 765: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 766: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 767: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 768: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 769: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 770: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 771: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 772: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 773: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 774: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# ...
# 2186: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2187: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2188: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2189: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2190: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2191: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2192: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2193: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2194: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2195: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2196: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2197: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2198: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2199: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2200: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2201: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2202: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2203: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2204: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2205: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2206: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2207: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2208: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2209: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2210: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2211: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2212: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2213: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2214: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2215: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2216: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2217: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2218: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2219: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2220: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2221: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2222: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2223: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2224: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2225: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2226: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2227: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2228: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2229: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2230: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2231: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2232: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2233: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2234: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2235: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2236: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2237: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2238: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2239: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2240: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2241: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2242: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2243: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2244: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2245: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2246: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2247: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2248: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2249: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2250: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2251: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2252: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2253: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2254: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2255: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2256: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2257: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2258: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2259: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2260: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2261: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2262: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2263: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2264: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2265: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2266: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2267: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2268: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2269: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2270: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2271: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2272: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2273: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2274: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2275: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2276: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2277: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2278: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2279: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2280: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2281: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2282: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2283: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2284: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2285: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2286: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2287: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2288: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2289: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2290: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2291: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2292: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2293: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2294: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2295: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2296: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2297: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2298: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2299: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2300: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2301: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2302: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2303: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2304: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2305: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2306: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2307: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2308: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2309: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2310: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2311: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2312: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2313: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2314: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2315: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2316: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2317: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2318: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2319: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2320: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2321: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2322: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2323: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2324: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2325: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2326: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2327: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2328: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2329: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2330: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2331: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2332: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2333: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2334: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2335: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2336: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2337: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2338: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2339: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2340: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2341: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2342: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2343: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2344: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2345: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2346: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2347: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2348: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2349: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2350: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2351: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2352: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2353: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2354: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2355: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2356: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2357: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2358: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2359: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2360: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2361: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2362: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2363: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2364: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2365: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2366: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2367: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2368: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2369: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2370: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2371: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2372: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2373: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2374: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2375: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2376: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2377: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2378: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2379: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2380: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2381: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2382: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2383: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2384: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2385: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2386: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2387: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2388: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2389: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2390: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2391: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2392: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2393: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2394: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2395: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2396: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2397: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2398: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2399: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2400: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2401: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2402: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2403: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2404: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2405: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2406: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2407: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2408: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2409: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2410: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2411: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2412: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2413: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2414: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2415: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2416: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2417: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2418: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2419: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2420: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2421: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2422: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2423: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2424: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2425: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2426: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2427: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2428: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2429: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2430: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2431: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2432: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2433: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2434: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2435: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2436: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2437: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2438: 1
# Querying https://api.yelp.com/v3/businesses/search ...
# 2439: 1

# %%
len(nightLife)
# Out:
# 2440

# %%
businesses = []
for b in nightLife:
    businesses += b['businesses']

# %%
len(businesses)
# Out:
# 2440

# %%
businessesSet = []
businessIds = []
for b in businesses:
    if b['id'] not in businessIds:
        businessIds.append(b['id'])
        businessesSet.append(b)

# %%
len(businessesSet)
# Out:
# 1484

# %%
# name, price, lat, lon, rating, review_count

# %%
cleanbusiness = []
for b in businesses:
    bus = {}
    bus['name'] = b['name']
    if 'price' in b:
        bus['price'] = len(b['price'])
    if 'coordinates' in b:
        bus['lat']= b['coordinates']['latitude']
        bus['lon']= b['coordinates']['longitude']
    if 'rating' in b:
        bus['rating'] = b['rating']
    if 'review_count' in b:
        bus['review_count'] = b['review_count']
    cleanbusiness.append(bus)

# %%
businessDF = pd.DataFrame(cleanbusiness)
businessDF.head()
# Out:
#          lat        lon                    name  price  rating  review_count
# 0  40.544233 -74.140982             Marina Cafe    2.0     3.0           238
# 1  40.729670 -73.999000                Zinc Bar    2.0     4.0           175
# 2  40.544233 -74.140982             Marina Cafe    2.0     3.0           238
# 3  40.866633 -73.928326  Pat'e Palo Bar & Grill    2.0     3.5            60
# 4  40.635009 -74.020043                  Memose    NaN     5.0             5

# %%
businessDF = businessDF[['name','price','rating' ,'review_count']]

# %%
result = pd.concat([barLocDF, businessDF], axis=1, sort=False)

# %%
len(result)
# Out:
# 2440

# %%
result.head(3)
# Out:
#          Location Type  Incident Zip           City        Borough   Latitude  \
# 0  Club/Bar/Restaurant       10308.0  STATEN ISLAND  STATEN ISLAND  40.544096
# 1  Club/Bar/Restaurant       10012.0       NEW YORK      MANHATTAN  40.729793
# 2  Club/Bar/Restaurant       10308.0  STATEN ISLAND  STATEN ISLAND  40.544209
#
#    Longitude  num_calls         name  price  rating  review_count
# 0 -74.141155         40  Marina Cafe    2.0     3.0           238
# 1 -73.998842         18     Zinc Bar    2.0     4.0           175
# 2 -74.141040         21  Marina Cafe    2.0     3.0           238

# %%
# converting latitude longitude into geometry POINT
result['lonlat'] = list(zip(result["Longitude"].values,result["Latitude"].values))
result['geometry'] = result[['lonlat']].applymap(lambda x:shapely.geometry.Point(x))

# %%
crs = {'init': 'epsg:4326'}
resultGDF = gpd.GeoDataFrame(result, crs = crs)

# %%
resultGDF.head(2)
# Out:
#          Location Type  Incident Zip           City        Borough  num_calls  \
# 0  Club/Bar/Restaurant       10308.0  STATEN ISLAND  STATEN ISLAND         40
# 1  Club/Bar/Restaurant       10012.0       NEW YORK      MANHATTAN         18
#
#           name  price  rating  review_count  \
# 0  Marina Cafe    2.0     3.0           238
# 1     Zinc Bar    2.0     4.0           175
#
#                                        geometry
# 0  POINT (-74.14115468967245 40.54409608878922)
# 1  POINT (-73.99884181131429 40.72979348359966)

# %%
resultGDF.drop(['Latitude', 'Longitude', 'lonlat'], axis=1, inplace=True)

# %%
resultGDF.to_file("combined/bars.shp")

# %%
resultGDF.corr()
# Out:
#               Incident Zip  num_calls     price    rating  review_count
# Incident Zip      1.000000   0.016136 -0.192472  0.069093     -0.221579
# num_calls         0.016136   1.000000  0.007325  0.024085     -0.017262
# price            -0.192472   0.007325  1.000000 -0.119493      0.169331
# rating            0.069093   0.024085 -0.119493  1.000000      0.018566
# review_count     -0.221579  -0.017262  0.169331  0.018566      1.000000

# %%
resultGDF.drop_duplicates(subset ='name',keep='first').corr()
# Out:
#               Incident Zip  num_calls     price    rating  review_count
# Incident Zip      1.000000   0.036441 -0.198181  0.070876     -0.238702
# num_calls         0.036441   1.000000  0.021521  0.024716     -0.026879
# price            -0.198181   0.021521  1.000000 -0.103930      0.156845
# rating            0.070876   0.024716 -0.103930  1.000000      0.019851
# review_count     -0.238702  -0.026879  0.156845  0.019851      1.000000
